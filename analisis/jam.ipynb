# %%
import utils
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely
import contextily as cx

# %%
_, jams = utils.load_data()

# %%
jams.line
# Out:
# 0        [{'x': -70.399254, 'y': -23.652352}, {'x': -70...
# 1        [{'x': -70.380121, 'y': -23.570454}, {'x': -70...
# 2        [{'x': -70.39178, 'y': -23.641992}, {'x': -70....
# 3        [{'x': -70.400993, 'y': -23.64724}, {'x': -70....
# 4        [{'x': -70.402302, 'y': -23.65233}, {'x': -70....
#                                ...
# 64456    [{'x': -70.404873, 'y': -23.672446}, {'x': -70...
# 64457    [{'x': -70.390625, 'y': -23.614888}, {'x': -70...
# 64458    [{'x': -70.382331, 'y': -23.62417}, {'x': -70....
# 64459    [{'x': -70.406463, 'y': -23.668251}, {'x': -70...
# 64460    [{'x': -70.38395, 'y': -23.651858}, {'x': -70....
# Name: line, Length: 64461, dtype: object

# %%
shapely.geometry.LineString({(0, 0), (1, 1), (2, 2)})
jams.line[0][0].values()
# Out:
# dict_values([-70.399254, -23.652352])

# %%
lines = []

for line in jams.line:
    lines.append(shapely.geometry.LineString([l.values() for l in line]))

lines[:5]
# Out:
# [<LINESTRING (-70.399 -23.652, -70.4 -23.653, -70.401 -23.654, -70.401 -23.65...>,
#  <LINESTRING (-70.38 -23.57, -70.379 -23.57, -70.379 -23.57, -70.378 -23.57, ...>,
#  <LINESTRING (-70.392 -23.642, -70.391 -23.641, -70.391 -23.64)>,
#  <LINESTRING (-70.401 -23.647, -70.401 -23.648, -70.4 -23.649, -70.399 -23.64...>,
#  <LINESTRING (-70.402 -23.652, -70.402 -23.653, -70.401 -23.653, -70.401 -23....>]

# %%
jams['geometry'] = lines

# %%
jams.head()
# Out:
#   country  level         city  \
# 0      CI      4  Antofagasta
# 1      CI      2  Antofagasta
# 2      CI      3  Antofagasta
# 3      CI      2  Antofagasta
# 4      CI      4  Antofagasta
#
#                                                 line  speedKMH  length  \
# 0  [{'x': -70.399254, 'y': -23.652352}, {'x': -70...      7.16     460
# 1  [{'x': -70.380121, 'y': -23.570454}, {'x': -70...      8.14     289
# 2  [{'x': -70.39178, 'y': -23.641992}, {'x': -70....      4.85     261
# 3  [{'x': -70.400993, 'y': -23.64724}, {'x': -70....      7.89     426
# 4  [{'x': -70.402302, 'y': -23.65233}, {'x': -70....      5.27     206
#
#   turnType        uuid               endNode     speed  \
# 0     NONE  1865151336            Av. Grecia  1.988889
# 1     NONE  1873528430     Hilda Cruz Colina  2.261111
# 2     NONE  1874194098          Buenos Aires  1.347222
# 3     NONE  1874163736        Carlos Condell  2.191667
# 4     NONE  1869436380  Manuel Antonio Matta  1.463889
#
#                                             segments  roadType  delay  \
# 0  [{'fromNode': 154041881, 'ID': 146613604, 'toN...         2    168
# 1  [{'fromNode': 325756858, 'ID': 424309812, 'toN...         1     74
# 2  [{'fromNode': 156882036, 'ID': 153183588, 'toN...         1    138
# 3  [{'fromNode': 163164452, 'ID': 162892853, 'toN...         2     92
# 4  [{'fromNode': 163785101, 'ID': 164443929, 'toN...         1    109
#
#                  street          id      pubMillis     endreport  \
# 0  Manuel Antonio Matta  1865151336  1724422622058  1.724425e+12
# 1          Félix García  1873528430  1724424984813  1.724425e+12
# 2             Caracoles  1874194098  1724425158457  1.724425e+12
# 3                 Maipú  1874163736  1724425158013  1.724425e+12
# 4               Copiapó  1869436380  1724423844413  1.724425e+12
#
#   blockingAlertUuid startNode  \
# 0               NaN       NaN
# 1               NaN       NaN
# 2               NaN       NaN
# 3               NaN       NaN
# 4               NaN       NaN
#
#                                             geometry
# 0  LINESTRING (-70.399254 -23.652352, -70.400116 ...
# 1  LINESTRING (-70.380121 -23.570454, -70.379359 ...
# 2  LINESTRING (-70.39178 -23.641992, -70.39138 -2...
# 3  LINESTRING (-70.400993 -23.64724, -70.400528 -...
# 4  LINESTRING (-70.402302 -23.65233, -70.401754 -...

# %%
jams_filtered = jams[['speedKMH', 'level', 'length', 'street', 'delay', 'pubMillis', 'endreport', 'geometry']]

# %%
jams_filtered.head()
# Out:
#    speedKMH  level  length                street  delay      pubMillis  \
# 0      7.16      4     460  Manuel Antonio Matta    168  1724422622058
# 1      8.14      2     289          Félix García     74  1724424984813
# 2      4.85      3     261             Caracoles    138  1724425158457
# 3      7.89      2     426                 Maipú     92  1724425158013
# 4      5.27      4     206               Copiapó    109  1724423844413
#
#       endreport                                           geometry
# 0  1.724425e+12  LINESTRING (-70.399254 -23.652352, -70.400116 ...
# 1  1.724425e+12  LINESTRING (-70.380121 -23.570454, -70.379359 ...
# 2  1.724425e+12  LINESTRING (-70.39178 -23.641992, -70.39138 -2...
# 3  1.724425e+12  LINESTRING (-70.400993 -23.64724, -70.400528 -...
# 4  1.724425e+12  LINESTRING (-70.402302 -23.65233, -70.401754 -...

# %%
jams_geo = gpd.GeoDataFrame(jams_filtered, geometry='geometry')
jams_geo = jams_geo.set_crs(epsg=4326)
jams_geo = jams_geo.to_crs(epsg=3857)
jams_geo.head()
# Out:
#    speedKMH  level  length                street  delay      pubMillis  \
# 0      7.16      4     460  Manuel Antonio Matta    168  1724422622058
# 1      8.14      2     289          Félix García     74  1724424984813
# 2      4.85      3     261             Caracoles    138  1724425158457
# 3      7.89      2     426                 Maipú     92  1724425158013
# 4      5.27      4     206               Copiapó    109  1724423844413
#
#       endreport                                           geometry
# 0  1.724425e+12  LINESTRING (-7836809.108 -2711102.546, -783690...
# 1  1.724425e+12  LINESTRING (-7834679.232 -2701152.733, -783459...
# 2  1.724425e+12  LINESTRING (-7835977.106 -2709843.563, -783593...
# 3  1.724425e+12  LINESTRING (-7837002.692 -2710481.305, -783695...
# 4  1.724425e+12  LINESTRING (-7837148.409 -2711099.872, -783708...

# %%
fig, ax = plt.subplots()
fig.set_size_inches((7, 12))
jams_geo.plot(ax=ax, column='speedKMH', legend=True, legend_kwds={'label': "Speed (km/h)"}, alpha=0.5, cmap='Reds')
cx.add_basemap(ax, source=cx.providers.OpenStreetMap.Mapnik, zoom=12)
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.title('Congestión en Antofagasta')
# Out:
# Text(0.5, 1.0, 'Congestión en Antofagasta')

# %%
fig, ax = plt.subplots()
fig.set_size_inches((7, 12))
jams_geo.plot(ax=ax, column='level', legend=True, legend_kwds={'label': "Nivel congestión"}, alpha=0.5, cmap='Reds')
cx.add_basemap(ax, source=cx.providers.OpenStreetMap.Mapnik, zoom=12)
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.title('Congestión en Antofagasta')
plt.show()

# %%
jams_geo['street'].value_counts()[:10]
# Out:
# street
# Av. Óscar Bonilla              2653
# Av. Pedro Aguirre Cerda        1939
# 14 de Febrero                  1903
# Av. Iquique                    1683
# Av. Edmundo Pérez Zujovic      1590
# Luis Uribe                     1483
# José Santos Ossa               1472
# Manuel Antonio Matta           1465
# Almirante Juan José Latorre    1441
# Salvador Reyes                 1375
# Name: count, dtype: int64

# %%
jams_count = jams_geo[['street']].groupby('street').size().reset_index(name='count')
jams_count = jams_count.sort_values(by='count', ascending=False)
jams_count = pd.merge(jams_count, jams_geo[['street', 'geometry']], on='street')
jams_count = gpd.GeoDataFrame(jams_count, geometry='geometry')

# %%
fig, ax = plt.subplots()
fig.set_size_inches((7, 12))
jams_count.plot(ax=ax, column='count', legend=True, legend_kwds={'label': "Cantidad"}, cmap='Reds')
cx.add_basemap(ax, source=cx.providers.OpenStreetMap.Mapnik, zoom=12)
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.title('Congestión en Antofagasta')
plt.show()

# %%
jams_avg = jams_geo[['speedKMH', 'level', 'street']].groupby('street').mean().reset_index()
jams_avg = pd.merge(jams_avg, jams_geo[['street', 'geometry']], on='street', how='left')
jams_avg = gpd.GeoDataFrame(jams_avg, geometry='geometry')

# %%
fig, ax = plt.subplots()
fig.set_size_inches((7, 12))
jams_avg.plot(ax=ax, column='speedKMH', legend=True, legend_kwds={'label': "Speed (km/h)"}, alpha=0.5, cmap='Reds')
cx.add_basemap(ax, source=cx.providers.OpenStreetMap.Mapnik, zoom=12)
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.title('Congestión en Antofagasta')
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches((7, 12))
jams_avg.plot(ax=ax, column='level', legend=True, legend_kwds={'label': "Nivel congestión"}, alpha=0.5, cmap='Reds')
cx.add_basemap(ax, source=cx.providers.OpenStreetMap.Mapnik, zoom=12)
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.title('Congestión en Antofagasta')
plt.show()
